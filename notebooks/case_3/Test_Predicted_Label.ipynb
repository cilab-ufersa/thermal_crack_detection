# %% [markdown]
# Treinamento com o dataset Crack Thermal Images - Pastas no-crack-images e crack-augmented

# %% [markdown]
# 1. Importação das bibliotecas

# %%
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats
import tensorflow as tf
from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# 2. Carregando o dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder='/content/drive/MyDrive/dataset'

# %% [markdown]
# 3. Estruturando o dataset

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['crack-augmented', 'no-crack-images']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# /content/drive/MyDrive/dataset/crack-augmented
# /content/drive/MyDrive/dataset/no-crack-images

# %%
i = 0
for classes in ['crack-augmented', 'no-crack-images']:
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f))]
    for _file in onlyfiles:
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width))
        x = img_to_array(img)
        dataset[i] = x
        mapping = {'crack-augmented': 0 , 'no-crack-images' : 1}
        y_dataset.append(mapping[classes])
        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %% [markdown]
# 6. Normalizando os dados

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['crack-augmented', 'no-crack-images']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
num_images_per_class = 1
num_cols = num_classes
num_rows = num_images_per_class

# %%
# Cria uma figura com uma grade de subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, 5))

# Loop através de cada classe
for i in range(num_classes):
    # Obtém o índice da primeira imagem da classe
    idx = first_image_index[i]

    # Obtém a imagem e converte para RGB
    pixels = dataset[idx]

    # Exibe a imagem no subplot correspondente
    axes[i].imshow(pixels, cmap='Spectral')
    axes[i].axis('off')

    # Adiciona um título para o subplot com o rótulo
    axes[i].set_title(f'{classes[i]}')

# Exibe a figura
plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Normalizando o dataset

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Trim dataset to match the size of y_dataset_
dataset_trimmed = dataset[:len(y_dataset_)]

# Now both dataset_trimmed and y_dataset_ have the same size
# You can then proceed with splitting or any other operations

# Splitting into training and test sets
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_, test_size=0.2)

print("Train set size: {0}, Test set size: {1}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 505, Test set size: 127

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 7000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 14000
# Tamanho do conjunto de teste: 127
# Classe 0: 7000 amostras
# Classe 1: 7000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/normalization/batch_normalization.py:143: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ batch_normalization                  │ (None, 48, 48, 3)           │              12 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 48, 48, 512)         │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 36864)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │       1,179,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %% [markdown]
# 4. Compilando o modelo

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20)

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.9187 - loss: 0.2950 - val_accuracy: 0.8525 - val_loss: 0.2623
# Epoch 2/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 60ms/step - accuracy: 1.0000 - loss: 1.1915e-04 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 3/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 4.4459e-05 - val_accuracy: 1.0000 - val_loss: 1.5959e-05
# Epoch 4/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 1.0000 - loss: 2.9334e-05 - val_accuracy: 1.0000 - val_loss: 2.8582e-06
# Epoch 5/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 3.4168e-05 - val_accuracy: 1.0000 - val_loss: 1.2565e-06
# Epoch 6/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 1.0000 - loss: 1.5345e-05 - val_accuracy: 1.0000 - val_loss: 8.1278e-07
# Epoch 7/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 8.5953e-06 - val_accuracy: 1.0000 - val_loss: 4.3702e-07
# Epoch 8/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9989 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 4.3499e-05
# Epoch 9/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 4.8893e-05 - val_accuracy: 1.0000 - val_loss: 3.0682e-07
# Epoch 10/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - accuracy: 1.0000 - loss: 6.8008e-06 - val_accuracy: 1.0000 - val_loss: 9.3535e-08
# Epoch 11/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 4.8930e-06 - val_accuracy: 1.0000 - val_loss: 7.0631e-08
# Epoch 12/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 1.0321e-06 - val_accuracy: 1.0000 - val_loss: 6.8332e-08
# Epoch 13/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 5.4066e-06 - val_accuracy: 1.0000 - val_loss: 5.7731e-08
# Epoch 14/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 1.2165e-06 - val_accuracy: 1.0000 - val_loss: 4.4660e-08
# Epoch 15/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 1.0000 - loss: 1.8690e-06 - val_accuracy: 1.0000 - val_loss: 2.6183e-08
# Epoch 16/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - accuracy: 1.0000 - loss: 5.0467e-06 - val_accuracy: 1.0000 - val_loss: 1.4561e-08
# Epoch 17/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 9.6203e-06 - val_accuracy: 1.0000 - val_loss: 6.8971e-09
# Epoch 18/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 1.2910e-06 - val_accuracy: 1.0000 - val_loss: 6.0882e-09
# Epoch 19/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 1.7460e-06 - val_accuracy: 1.0000 - val_loss: 3.0228e-09
# Epoch 20/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 1.3370e-06 - val_accuracy: 1.0000 - val_loss: 7.2377e-10
# Epoch 21/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 1.0000 - loss: 4.0248e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 22/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 6.7504e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 23/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 2.6021e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 24/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - accuracy: 1.0000 - loss: 6.5183e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 25/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 2.6757e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 26/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 2.7377e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 27/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 4.9680e-08 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 28/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 5.5507e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 29/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 1.5448e-07 - val_accuracy: 1.0000 - val_loss: 3.4060e-10
# Epoch 30/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 2.8548e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 31/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 2.0667e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 32/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - accuracy: 1.0000 - loss: 5.2638e-08 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 33/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 7.3820e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 34/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - accuracy: 1.0000 - loss: 8.2150e-08 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 35/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 1.1317e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 36/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - accuracy: 1.0000 - loss: 2.0862e-07 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 37/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 63ms/step - accuracy: 1.0000 - loss: 3.5795e-08 - val_accuracy: 1.0000 - val_loss: 1.7030e-10
# Epoch 38/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 63ms/step - accuracy: 1.0000 - loss: 3.6956e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 39/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 1.0000 - loss: 4.2181e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 40/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9979 - val_loss: 0.2128
# Epoch 41/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 63ms/step - accuracy: 0.9958 - loss: 0.0972 - val_accuracy: 0.9979 - val_loss: 0.0612
# Epoch 42/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.1382e-05
# Epoch 43/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9999 - loss: 1.8904e-04 - val_accuracy: 1.0000 - val_loss: 5.9605e-10
# Epoch 44/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 1.0000 - loss: 1.3323e-06 - val_accuracy: 1.0000 - val_loss: 5.9605e-10
# Epoch 45/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 1.0000 - loss: 1.6360e-07 - val_accuracy: 1.0000 - val_loss: 2.9802e-10
# Epoch 46/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 1.0096e-07 - val_accuracy: 1.0000 - val_loss: 2.9802e-10
# Epoch 47/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 1.0000 - loss: 2.5335e-06 - val_accuracy: 1.0000 - val_loss: 2.9802e-10
# Epoch 48/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 1.0000 - loss: 3.5990e-07 - val_accuracy: 1.0000 - val_loss: 2.9802e-10
# Epoch 49/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 1.3257e-06 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 50/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 1.0000 - loss: 6.7105e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 51/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 1.0000 - loss: 6.7988e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 52/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 1.0000 - loss: 8.4442e-07 - val_accuracy: 1.0000 - val_loss: 5.9605e-10
# Epoch 53/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 1.0000 - loss: 6.9337e-07 - val_accuracy: 1.0000 - val_loss: 2.9802e-10
# Epoch 54/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 3.0956e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 55/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 1.0000 - loss: 2.0402e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 56/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 3.3858e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 57/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - accuracy: 1.0000 - loss: 4.1388e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 58/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 1.0000 - loss: 9.7704e-09 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
val_accuracy = history.history['val_accuracy']

mean_val_accuracy = np.mean(val_accuracy)

print("Valor médio de acurácia:", mean_val_accuracy)
# Out:
# Valor médio de acurácia: 0.9973830056601557

# %% [markdown]
# 5. Carregando o modelo

# %%
import pandas as pd
history_save = pd.DataFrame(history.history)
history_save.to_csv('datasetThermal.csv')

# %%
# save model structure in jason file
model_json = model.to_json()
with open("thermal_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modelosalvo1.keras')

# %%
from keras.models import load_model

modelo_carregado = load_model('/content/modelosalvo1.keras')

# %%
import pandas as pd

history = pd.read_csv('/content/datasetThermal.csv')

# %% [markdown]
# 6. Plotando o modelo

# %%
import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])


plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc = 'upper right')
plt.show()

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Acurácia')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# 7. Salvando o modelo

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative Positive'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[61  1]
#  [ 0 65]]

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(10,10))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='Spectral')
        plt.title('Real: {}\nPredito: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]))
        plt.axis('off')
    plt.show()

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image
import numpy as np
import tensorflow as tf
import io

# %%
# Carregar o modelo salvo no formato .keras
model = tf.keras.models.load_model('modelosalvo1.keras')

# Definir os rótulos das classes (ajuste conforme seu modelo)
class_labels = {0: 'Positive', 1: 'Negative'}

# Widget para upload de arquivos
upload_button = widgets.FileUpload(accept='.jpg,.png', multiple=False)

# Widgets para exibir a imagem e o resultado
image_widget = widgets.Output()
result_widget = widgets.Output()

# %%
def classify_image(change):
    with image_widget:
        image_widget.clear_output()
    with result_widget:
        result_widget.clear_output()

    # Verificar se algum arquivo foi enviado
    if len(upload_button.value) == 0:
        with result_widget:
            print("Nenhum arquivo foi enviado.")
        return

    # Obter arquivo do widget
    file = list(upload_button.value.values())[0]
    content = file['content']

    try:

        # Abrir e preparar a imagem
        img = Image.open(io.BytesIO(content)).convert('RGB')
        img_resized = img.resize((48, 48))  # Ajuste o tamanho conforme necessário
        img_array = np.array(img_resized) / 255.0  # Normalizar entre 0 e 1

        # Achatando a imagem para o formato esperado pelo modelo
        img_input = np.expand_dims(img_array, axis=0) # Forma (1, 150528)

        # Classificar a imagem
        prediction = model.predict(img_input)
        predicted_class_idx = np.argmax(prediction, axis=1)[0]
        predicted_label = class_labels.get(predicted_class_idx, "Classe desconhecida")

        # Exibir a imagem
        with image_widget:
            display(img)


       # Exibir a classe prevista
        with result_widget:
            print(f"Predicted Label: {predicted_label}")
            print("Probability")
            for idx, prob in enumerate(prediction[0]):
                label = class_labels.get(idx, f"Classe {idx}")
                print(f"{label}: {prob*100:.2f}%")

    except Exception as e:
        with result_widget:
            print(f"Ocorreu um erro ao processar a imagem: {e}")

# %%
# Acionar a função ao enviar o arquivo
upload_button.observe(classify_image, names='value')

# Exibir os widgets no notebook
display(widgets.VBox([upload_button, image_widget, result_widget]))
# Out:
# VBox(children=(FileUpload(value={'FLIR1868.jpg': {'metadata': {'name': 'FLIR1868.jpg', 'type': 'image/jpeg', '…
